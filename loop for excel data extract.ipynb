# %%
import pandas as pd

target = ['9601','9602','9603','9604','9605','9606','9607','9608','9609','9610','9611','9612','9701','9702','9703','9704','9705','9706','9707','9708','9709','9710','9711','9712','9801','9802','9803','9804','9805','9806','9807','9808','9809','9810','9811','9812','9901','9902','9903','9904','9905','9906','9907','9908','9909','9910','9911','9912','10001','10002','10003','10004','10005','10006','10007','10008','10009','10010','10011','10012','10101','10102','10103','10104','10105','10106','10107','10108','10109','10110','10111','10112','10201','10202','10203','10204','10205','10206','10207','10208','10209','10210','10211','10212','10301','10302','10303','10304','10305','10306','10307','10308','10309','10310','10311','10312'
          ,'10401','10402','10403','10404','10405','10406','10407','10408','10409','10410','10411','10412','10501','10502','10503','10504','10505','10506'
          ,'10507','10508','10509','10510','10511']

#,'10512','10602','10603'
result = []

for period in target:
    url = 'http://trans.nfa.gov.tw/statisrpt/{}/1176400010.xls'.format(period)
    x = pd.read_excel(url)
    try:
        y = x['內政部消防署(火災調查組)'].iloc[7]
        result.append(str(period)+'\t'+str(y))
    except:
        pass
print(result)
# Out:
# ['9601\t338', '9602\t328', '9603\t338', '9605\t262', '9606\t240', '9607\t279', '9608\t258', '9609\t223', '9610\t285', '9611\t259', '9612\t280', '9701\t270', '9702\t286', '9703\t266', '9704\t204', '9705\t218', '9706\t211', '9707\t212', '9708\t236', '9709\t235', '9710\t211', '9711\t257', '9712\t280', '9801\t348', '9802\t227', '9803\t246', '9804\t204', '9805\t220', '9806\t185', '9807\t165', '9808\t158', '9809\t213', '9810\t195', '9811\t230', '9812\t230', '9901\t218', '9902\t207', '9903\t251', '9904\t194', '9905\t182', '9906\t135', '9907\t196', '9908\t171', '9909\t130', '9910\t151', '9911\t169', '9912\t182', '10001\t202', '10002\t200', '10003\t171', '10004\t164', '10005\t123', '10006\t154', '10007\t122', '10008\t120', '10009\t146', '10010\t114', '10011\t108', '10012\t148', '10101\t142', '10102\t124', '10103\t146', '10104\t135', '10105\t110', '10106\t107', '10107\t135', '10108\t129', '10109\t140', '10110\t163', '10111\t131', '10112\t112', '10201\t131', '10202\t147', '10203\t135', '10204\t
# ...

# %%
for period in ['10602','10603']:
    url = 'http://trans.nfa.gov.tw/statisrpt/{}/1176400010.xls'.format(period)
    x = pd.read_excel(url)
    y = x['次月底前編報'].iloc[7]+x['月　　　報'].iloc[7]
    result.append(str(period)+'\t'+str(y))

# %%
print(result)
# Out:
# ['9601\t338', '9602\t328', '9603\t338', '9605\t262', '9606\t240', '9607\t279', '9608\t258', '9609\t223', '9610\t285', '9611\t259', '9612\t280', '9701\t270', '9702\t286', '9703\t266', '9704\t204', '9705\t218', '9706\t211', '9707\t212', '9708\t236', '9709\t235', '9710\t211', '9711\t257', '9712\t280', '9801\t348', '9802\t227', '9803\t246', '9804\t204', '9805\t220', '9806\t185', '9807\t165', '9808\t158', '9809\t213', '9810\t195', '9811\t230', '9812\t230', '9901\t218', '9902\t207', '9903\t251', '9904\t194', '9905\t182', '9906\t135', '9907\t196', '9908\t171', '9909\t130', '9910\t151', '9911\t169', '9912\t182', '10001\t202', '10002\t200', '10003\t171', '10004\t164', '10005\t123', '10006\t154', '10007\t122', '10008\t120', '10009\t146', '10010\t114', '10011\t108', '10012\t148', '10101\t142', '10102\t124', '10103\t146', '10104\t135', '10105\t110', '10106\t107', '10107\t135', '10108\t129', '10109\t140', '10110\t163', '10111\t131', '10112\t112', '10201\t131', '10202\t147', '10203\t135', '10204\t
# ...
